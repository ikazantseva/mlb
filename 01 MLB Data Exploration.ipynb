# %%
import pandas as pd

# %%
#Import dataset:

# %%
mlb = pd.read_csv('/Users/nikolay/Desktop/MLB dataset/baseballdata.csv')

# %%
mlb.head()   #use .tail() to see the final rows
# Out:
#    Unnamed: 0  Rk  Year                    Tm       Lg    G   W   L  Ties  \
# 0           1   1  2016  Arizona Diamondbacks  NL West  162  69  93     0
# 1           2   2  2015  Arizona Diamondbacks  NL West  162  79  83     0
# 2           3   3  2014  Arizona Diamondbacks  NL West  162  64  98     0
# 3           4   4  2013  Arizona Diamondbacks  NL West  162  81  81     0
# 4           5   5  2012  Arizona Diamondbacks  NL West  162  81  81     0
#
#     W.L.          ...             R   RA Attendance BatAge  PAge  X.Bat X.P  \
# 0  0.426          ...           752  890  2,036,216   26.7  26.4     50  29
# 1  0.488          ...           720  713  2,080,145   26.6  27.1     50  27
# 2  0.395          ...           615  742  2,073,730   27.6  28.0     52  25
# 3  0.500          ...           685  695  2,134,895   28.1  27.6     44  23
# 4  0.500          ...           734  688  2,177,617   28.3  27.4     48  23
#
# ...

# %%
len(mlb) #2594 rows imported
# Out:
# 2594

# %%
mlb.columns #name of the columns
# Out:
# Index(['Unnamed: 0', 'Rk', 'Year', 'Tm', 'Lg', 'G', 'W', 'L', 'Ties', 'W.L.',
#        'pythW.L.', 'Finish', 'GB', 'Playoffs', 'R', 'RA', 'Attendance',
#        'BatAge', 'PAge', 'X.Bat', 'X.P', 'Top.Player', 'Managers', 'current'],
#       dtype='object')

# %%
len(mlb.columns) #24 columns
# Out:
# 24

# %%
mlb.info() #type of the data, missing number of rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2594 entries, 0 to 2593
# Data columns (total 24 columns):
# Unnamed: 0    2594 non-null int64
# Rk            2594 non-null int64
# Year          2594 non-null int64
# Tm            2594 non-null object
# Lg            2594 non-null object
# G             2594 non-null int64
# W             2594 non-null int64
# L             2594 non-null int64
# Ties          2594 non-null int64
# W.L.          2594 non-null float64
# pythW.L.      2594 non-null float64
# Finish        2594 non-null object
# GB            2594 non-null object
# Playoffs      431 non-null object
# R             2594 non-null int64
# RA            2594 non-null int64
# Attendance    2520 non-null object
# BatAge        2594 non-null float64
# PAge          2594 non-null float64
# X.Bat         2594 non-null int64
# X.P           2594 non-null int64
# Top.Player    2594 non-null object
# Managers      2594 non-null object
# current       2594 non-null object
# ...

# %%
mlb.describe() #get the statistics of the data
# Out:
#         Unnamed: 0           Rk         Year            G            W  \
# count  2594.000000  2594.000000  2594.000000  2594.000000  2594.000000
# mean   1297.500000    54.824981  1962.175019   155.188897    77.513878
# std     748.967623    37.413876    37.413876    12.548301    14.054629
# min       1.000000     1.000000  1876.000000    60.000000    17.000000
# 25%     649.250000    22.000000  1931.000000   154.000000    68.000000
# 50%    1297.500000    48.000000  1969.000000   161.000000    78.000000
# 75%    1945.750000    86.000000  1995.000000   162.000000    88.000000
# max    2594.000000   141.000000  2016.000000   165.000000   116.000000
#
#                  L         Ties         W.L.     pythW.L.            R  \
# count  2594.000000  2594.000000  2594.000000  2594.000000  2594.000000
# mean     76.925983     0.749036     0.502478     0.502547   694.480339
# std      14.629448     1.299325     0.084522     0.079307   113.883503
# ...

# %%
#Rename Columns:

# %%
mlb.columns = ['Unnamed: 0', 'Rk', 'Year', 'Team', 'League', 'GamePlayed', 'Wins', 'Losses', 'Ties', 'WinLoss%',
       'pythWinLoss', 'Finish', 'GamesBehind', 'Playoffs', 'RunsScored', 'OppontRunScored', 'Attendance',
       'BatAge', 'PAge', 'X.Bat', 'X.P', 'Top.Player', 'Managers', 'current']

# %%
mlb.head()
# Out:
#    Unnamed: 0  Rk  Year                  Team   League  GamePlayed  Wins  \
# 0           1   1  2016  Arizona Diamondbacks  NL West         162    69
# 1           2   2  2015  Arizona Diamondbacks  NL West         162    79
# 2           3   3  2014  Arizona Diamondbacks  NL West         162    64
# 3           4   4  2013  Arizona Diamondbacks  NL West         162    81
# 4           5   5  2012  Arizona Diamondbacks  NL West         162    81
#
#    Losses  Ties  WinLoss%          ...           RunsScored OppontRunScored  \
# 0      93     0     0.426          ...                  752             890
# 1      83     0     0.488          ...                  720             713
# 2      98     0     0.395          ...                  615             742
# 3      81     0     0.500          ...                  685             695
# 4      81     0     0.500          ...                  734             688
#
#   Attendance BatAge  PAge  X.Bat X.P           Top.Player  \
# ...

# %%
#Subsetting Dataframe:

# %%
#Extracting rows
mlb[50:101]
# Out:
#      Unnamed: 0  Rk  Year              Team   League  GamePlayed  Wins  \
# 50           51  32  1985    Atlanta Braves  NL West         162    66
# 51           52  33  1984    Atlanta Braves  NL West         162    80
# 52           53  34  1983    Atlanta Braves  NL West         162    88
# 53           54  35  1982    Atlanta Braves  NL West         162    89
# 54           55  36  1981    Atlanta Braves  NL West         107    50
# 55           56  37  1980    Atlanta Braves  NL West         161    81
# 56           57  38  1979    Atlanta Braves  NL West         160    66
# 57           58  39  1978    Atlanta Braves  NL West         162    69
# 58           59  40  1977    Atlanta Braves  NL West         162    61
# 59           60  41  1976    Atlanta Braves  NL West         162    70
# 60           61  42  1975    Atlanta Braves  NL West         161    67
# 61           62  43  1974    Atlanta Braves  NL West         163    88
# ...

# %%
mlb[::20] #every 20th row
# Out:
#       Unnamed: 0   Rk  Year                     Team      League  GamePlayed  \
# 0              1    1  2016     Arizona Diamondbacks     NL West         162
# 20            21    2  2015           Atlanta Braves     NL East         162
# 40            41   22  1995           Atlanta Braves     NL East         144
# 60            61   42  1975           Atlanta Braves     NL West         161
# 80            81   62  1955         Milwaukee Braves          NL         154
# 100          101   82  1935            Boston Braves          NL         153
# 120          121  102  1915            Boston Braves          NL         157
# 140          141  122  1895        Boston Beaneaters          NL         132
# 160          161    1  2016        Baltimore Orioles     AL East         162
# 180          181   21  1996        Baltimore Orioles     AL East         163
# 200          201   41  1976        Baltimore Orioles     AL East         162
# ...

# %%
#Extract columns
mlb.Year.head()
# Out:
# 0    2016
# 1    2015
# 2    2014
# 3    2013
# 4    2012
# Name: Year, dtype: int64

# %%
mlb[['Top.Player', 'Managers']].head()
# Out:
#             Top.Player                               Managers
# 0       J.Segura (5.7)                         C.Hale (69-93)
# 1  P.Goldschmidt (8.8)                         C.Hale (79-83)
# 2  P.Goldschmidt (4.5)  K.Gibson (63-96) and A.Trammell (1-2)
# 3  P.Goldschmidt (7.1)                       K.Gibson (81-81)
# 4         A.Hill (5.0)                       K.Gibson (81-81)

# %%
mlb[:10][['Top.Player', 'Wins']]
# Out:
#             Top.Player  Wins
# 0       J.Segura (5.7)    69
# 1  P.Goldschmidt (8.8)    79
# 2  P.Goldschmidt (4.5)    64
# 3  P.Goldschmidt (7.1)    81
# 4         A.Hill (5.0)    81
# 5        J.Upton (6.1)    94
# 6        C.Young (5.4)    65
# 7        D.Haren (7.1)    70
# 8        D.Haren (6.6)    82
# 9         B.Webb (5.9)    90

# %%
mlb['TotalGames'] = mlb.Wins + mlb.Losses + mlb.Ties

# %%
mlb[['TotalGames', 'GamePlayed']].head(20)  #to check that Wins+Losses+Ties equal to GamePlayed column
# Out:
#     TotalGames  GamePlayed
# 0          162         162
# 1          162         162
# 2          162         162
# 3          162         162
# 4          162         162
# 5          162         162
# 6          162         162
# 7          162         162
# 8          162         162
# 9          162         162
# 10         162         162
# 11         162         162
# 12         162         162
# 13         162         162
# 14         162         162
# 15         162         162
# 16         162         162
# 17         162         162
# 18         162         162
# 19         161         161

# %%
mlb.drop('TotalGames', 1) #to drop a column
# Out:
#       Unnamed: 0  Rk  Year                  Team   League  GamePlayed  Wins  \
# 0              1   1  2016  Arizona Diamondbacks  NL West         162    69
# 1              2   2  2015  Arizona Diamondbacks  NL West         162    79
# 2              3   3  2014  Arizona Diamondbacks  NL West         162    64
# 3              4   4  2013  Arizona Diamondbacks  NL West         162    81
# 4              5   5  2012  Arizona Diamondbacks  NL West         162    81
# 5              6   6  2011  Arizona Diamondbacks  NL West         162    94
# 6              7   7  2010  Arizona Diamondbacks  NL West         162    65
# 7              8   8  2009  Arizona Diamondbacks  NL West         162    70
# 8              9   9  2008  Arizona Diamondbacks  NL West         162    82
# 9             10  10  2007  Arizona Diamondbacks  NL West         162    90
# 10            11  11  2006  Arizona Diamondbacks  NL West         162    76
# ...
